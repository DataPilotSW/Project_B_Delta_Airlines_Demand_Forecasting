# %%
import pandas as pd
from pathlib import Path

# Root directory for Project B
PROJECT_ROOT = Path(r"C:\Users\Seb\Documents\Portfolio (Projects)\Aviation_AI_Projects\Project_B_Delta_Airlines_Demand_Forecasting")

DATA_DIR = PROJECT_ROOT / "data"
DELTA_DIR = DATA_DIR / "delta"
OUTPUT_DIR = PROJECT_ROOT / "output" / "clean"

OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

print("PROJECT_ROOT:", PROJECT_ROOT)
print("DELTA_DIR:", DELTA_DIR)
print("OUTPUT_DIR:", OUTPUT_DIR)
# Out:
# PROJECT_ROOT: C:\Users\Seb\Documents\Portfolio (Projects)\Aviation_AI_Projects\Project_B_Delta_Airlines_Demand_Forecasting
# DELTA_DIR: C:\Users\Seb\Documents\Portfolio (Projects)\Aviation_AI_Projects\Project_B_Delta_Airlines_Demand_Forecasting\data\delta
# OUTPUT_DIR: C:\Users\Seb\Documents\Portfolio (Projects)\Aviation_AI_Projects\Project_B_Delta_Airlines_Demand_Forecasting\output\clean

# %%
# Load all Delta CSVs
delta_files = sorted(list(DELTA_DIR.glob("DL-*.csv")))
delta_files
# Out:
# [WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-ATL.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-BOS.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-BWI.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-CLT.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-DCA.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-DEN.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-DFW.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-DTW.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-EWR.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-FLL.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-IAD.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-IAH.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-JFK.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-LAS.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-LAX.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-LGA.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-MCO.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-MIA.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-MSP.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-ORD.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-PDX.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-PHL.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-PHX.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-SAN.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-SEA.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-SFO.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-SLC.csv'),
#  WindowsPath('C:/Users/Seb/Documents/Portfolio (Projects)/Aviation_AI_Projects/Project_B_Delta_Airlines_Demand_Forecasting/data/delta/DL-TPA.csv')]

# %%
def load_delta_airport_csv(path):
    df = pd.read_csv(path)
    
    # Standardize columns
    df.columns = [c.lower().strip() for c in df.columns]
    
    # Rename common columns if necessary
    rename_map = {
        'month': 'date',
        'passengers': 'pax',
        'passenger': 'pax'
    }
    df = df.rename(columns=rename_map)
    
    # Convert date
    df['date'] = pd.to_datetime(df['date'])
    
    # Add airport code
    airport_code = path.stem.split("-")[1]  # e.g., "DL-ATL" → "ATL"
    df["airport"] = airport_code
    
    return df

# %%
delta_atl = load_delta_airport_csv(DELTA_DIR / "DL-ATL.csv")
delta_dtw = load_delta_airport_csv(DELTA_DIR / "DL-DTW.csv")
delta_msp = load_delta_airport_csv(DELTA_DIR / "DL-MSP.csv")

# %%
df_delta_all = pd.concat([delta_atl, delta_dtw, delta_msp], ignore_index=True)
df_delta_all.sort_values(["airport", "date"], inplace=True)
df_delta_all.head()
# Out:
#         date  asm_domestic  asm_international  flights_domestic  \
# 0 2002-10-01       2093602           887184.0             16535
# 1 2002-11-01       1999098           823130.0             15658
# 2 2002-12-01       2057104           783201.0             16038
# 3 2003-01-01       2068740           780766.0             16316
# 4 2003-02-01       1798127           633201.0             14080
#
#    flights_international  passengers_domestic  passengers_international  \
# 0                 1357.0              2120947                  176671.0
# 1                 1301.0              1993739                  172111.0
# 2                 1298.0              2159529                  183952.0
# 3                 1301.0              1880538                  169462.0
# 4                 1104.0              1776826                  143114.0
#
#    rpm_domestic  rpm_international airport
# 0       1527419           597313.0     ATL
# 1       1434927           566487.0     ATL
# 2       1615439           579713.0     ATL
# 3       1409105           536961.0     ATL
# 4       1307159           431583.0     ATL

# %%
# Individual
delta_atl.to_csv(OUTPUT_DIR / "delta_atl.csv", index=False)
delta_dtw.to_csv(OUTPUT_DIR / "delta_dtw.csv", index=False)
delta_msp.to_csv(OUTPUT_DIR / "delta_msp.csv", index=False)

# Combined
df_delta_all.to_csv(OUTPUT_DIR / "delta_all_hubs.csv", index=False)

print("Saved cleaned datasets:")
for f in OUTPUT_DIR.glob("*.csv"):
    print(" -", f.name)
# Out:
# Saved cleaned datasets:
#  - delta_all_hubs.csv
#  - delta_atl.csv
#  - delta_dtw.csv
#  - delta_msp.csv
